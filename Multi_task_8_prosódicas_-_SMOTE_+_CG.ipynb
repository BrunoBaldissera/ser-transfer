# %%
#https://drive.google.com/drive/folders/1t9D3qOnUDNJMOj93WUwCqxSioajGlfaT?usp=sharing

#prosodic https://drive.google.com/file/d/19qgv1nCXcSne91lqB_EGt0l_y5IwKIop/view?usp=sharing
# !gdown --id 19qgv1nCXcSne91lqB_EGt0l_y5IwKIop

#wav2vec https://drive.google.com/file/d/12MSE4dX5EJe3fkqRN8tFkVD23-f-wivV/view?usp=sharing
# !gdown --id 12MSE4dX5EJe3fkqRN8tFkVD23-f-wivV

#Bruno Gianesi SER Features:
#https://drive.google.com/file/d/1uB7Z4971WbfldIH_cWssXsSNZMH4HnwC/view?usp=sharing
#https://drive.google.com/file/d/1QlFFEuuIRr7YaT9YO341Hr7K0HFUy1jp/view?usp=sharing
#https://drive.google.com/file/d/1-yq9dq7vOuIkRMzSQqI_iA182b45Khs_/view?usp=sharing
# !gdown --id 1uB7Z4971WbfldIH_cWssXsSNZMH4HnwC
# !gdown --id 1QlFFEuuIRr7YaT9YO341Hr7K0HFUy1jp
# !gdown --id 1-yq9dq7vOuIkRMzSQqI_iA182b45Khs_

#Bruno Gianesi CETUC Features:
#https://drive.google.com/file/d/1mvfnPtJGzAOXCFVGCf6jdTe2F5Cw-EQm/view?usp=sharing
#https://drive.google.com/file/d/1hNow4VOsTbBpoMv0wCZCx9bQm9LiXqZ8/view?usp=sharing
#https://drive.google.com/file/d/1K1HfH-aU2_N1PEIk2vv8IEjX6zFSwhNx/view?usp=sharing
# !gdown --id 1mvfnPtJGzAOXCFVGCf6jdTe2F5Cw-EQm
# !gdown --id 1hNow4VOsTbBpoMv0wCZCx9bQm9LiXqZ8
# !gdown --id 1K1HfH-aU2_N1PEIk2vv8IEjX6zFSwhNx

# ----> dataset de teste e o change gender (estão no mesmo arquivo)
#https://drive.google.com/file/d/11FuuuUF2lj5mM2EC3b-HKvzw6codsiK2/view?usp=sharing
#https://drive.google.com/file/d/1a8D5Yj7CfHkjPnKGI7r2YI694gh80RKP/view?usp=sharing
#https://drive.google.com/file/d/1_zdkC2k30GGaIDR79rxF4u5BnxKfe8TB/view?usp=sharing
# !gdown --id 11FuuuUF2lj5mM2EC3b-HKvzw6codsiK2
# !gdown --id 1a8D5Yj7CfHkjPnKGI7r2YI694gh80RKP
# !gdown --id 1_zdkC2k30GGaIDR79rxF4u5BnxKfe8TB

#Features dataset test - prosodic e wav2vec
#https://drive.google.com/file/d/1bwIc5b5bgrUPn8fnmhCDyGUVG_K6h7nn/view?usp=sharing
#https://drive.google.com/file/d/155-9F4AOQnZIGh5TGLtwRRKlmDd6VInO/view?usp=sharing
# !gdown --id 1bwIc5b5bgrUPn8fnmhCDyGUVG_K6h7nn
# !gdown --id 155-9F4AOQnZIGh5TGLtwRRKlmDd6VInO

#Features dataset change gender - prosodic e wav2vec
#https://drive.google.com/file/d/1Y-HH961eOMkfUE3M-5LKFKgbMkpQh-wv/view?usp=sharing
#https://drive.google.com/file/d/1k_YG7dk_J4qtfKjxAdyjB1rfqS9_HO9K/view?usp=sharing
# !gdown --id 1Y-HH961eOMkfUE3M-5LKFKgbMkpQh-wv
# !gdown --id 1k_YG7dk_J4qtfKjxAdyjB1rfqS9_HO9K
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=19qgv1nCXcSne91lqB_EGt0l_y5IwKIop
# To: /content/prosodic_features.csv
# 100% 679k/679k [00:00<00:00, 51.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=12MSE4dX5EJe3fkqRN8tFkVD23-f-wivV
# To: /content/wav2vec_features.csv
# 100% 9.81M/9.81M [00:00<00:00, 59.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1uB7Z4971WbfldIH_cWssXsSNZMH4HnwC
# To: /content/SER_MFCCs_data.csv
# 100% 261k/261k [00:00<00:00, 67.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1QlFFEuuIRr7YaT9YO341Hr7K0HFUy1jp
# To: /content/SER_F0_data.csv
# 100% 127k/127k [00:00<00:00, 52.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-yq9dq7vOuIkRMzSQqI_iA182b45Khs_
# To: /content/SER_Features_data.csv
# 100% 115k/115k [00:00<00:00, 39.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1mvfnPtJGzAOXCFVGCf6jdTe2F5Cw-EQm
# To: /content/CETUC_Features_data.csv
# 100% 14.3M/14.3M [00:00<00:00, 86.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1hNow4VOsTbBpoMv0wCZCx9bQm9LiXqZ8
# To: /content/CETUC_F0_data.csv
# 100% 18.3M/18.3M [00:00<00:00, 111MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1K1HfH-aU2_N1PEIk2vv8IEjX6zFSwhNx
# To: /content/CETUC_MFCCs_data.csv
# 100% 22.4M/22.4M [00:00<00:00, 69.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=11FuuuUF2lj5mM2EC3b-HKvzw6codsiK2
# To: /content/bruno_test_change_F0_data.csv
# 100% 91.4k/91.4k [00:00<00:00, 66.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1a8D5Yj7CfHkjPnKGI7r2YI694gh80RKP
# To: /content/bruno_test_change_MFCCs_data.csv
# 100% 188k/188k [00:00<00:00, 27.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1_zdkC2k30GGaIDR79rxF4u5BnxKfe8TB
# To: /content/bruno_test_change_Features_data.csv
# 100% 84.1k/84.1k [00:00<00:00, 80.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1bwIc5b5bgrUPn8fnmhCDyGUVG_K6h7nn
# To: /content/test_prosodic_features.csv
# 100% 334k/334k [00:00<00:00, 46.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=155-9F4AOQnZIGh5TGLtwRRKlmDd6VInO
# To: /content/test_wav2vec_features.csv
# 100% 4.83M/4.83M [00:00<00:00, 42.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Y-HH961eOMkfUE3M-5LKFKgbMkpQh-wv
# To: /content/change_gender_prosodic_features.csv
# 100% 149k/149k [00:00<00:00, 55.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1k_YG7dk_J4qtfKjxAdyjB1rfqS9_HO9K
# To: /content/change_gender_wav2vec_features.csv
# 100% 2.09M/2.09M [00:00<00:00, 66.3MB/s]

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

# %%
scaler = MinMaxScaler(feature_range=(0, 1))

# %% [markdown]
# #DATASET CETUC

# %%
df_CETUC_1 = pd.read_csv('CETUC_Features_data.csv')
df_CETUC_2 = pd.read_csv('CETUC_F0_data.csv')
df_CETUC_3 = pd.read_csv('CETUC_MFCCs_data.csv')
df_CETUC_1_2 =  pd.merge(df_CETUC_1, df_CETUC_2, on=['FileName'], how='inner')
df_CETUC = pd.merge(df_CETUC_1_2, df_CETUC_3, on=['FileName'], how='inner')

dfs_CETUC = df_CETUC[['Gender_x', 'nobs', 'mean', 'skew', 'kurtosis', 'median', 'mode', 'std', 'low', 'peak', 'q25', 'q75', 'iqr',
        'nobs_pitch', 'mean_pitch', 'skew_pitch', 'kurtosis_pitch', 'median_pitch', 'mode_pitch', 'std_pitch', 'low_pitch', 'peak_pitch', 'q25_pitch', 'q75_pitch', 'iqr_pitch', 
        'MFCC_1', 'MFCC_2', 'MFCC_3', 'MFCC_4', 'MFCC_5', 'MFCC_6', 'MFCC_7', 'MFCC_8', 'MFCC_9', 'MFCC_10',
        'MFCC_11', 'MFCC_12', 'MFCC_13', 'MFCC_14', 'MFCC_15', 'MFCC_16', 'MFCC_17', 'MFCC_18', 'MFCC_19', 'MFCC_20']]

CETUC_norm = scaler.fit_transform(dfs_CETUC.iloc[:, 1:].values)
CETUC_norm.shape
dfs_CETUC_norm = pd.DataFrame(CETUC_norm, columns=['nobs', 'mean', 'skew', 'kurtosis', 'median', 'mode', 'std', 'low', 'peak', 'q25', 'q75', 'iqr',
        'nobs_pitch', 'mean_pitch', 'skew_pitch', 'kurtosis_pitch', 'median_pitch', 'mode_pitch', 'std_pitch', 'low_pitch', 'peak_pitch', 'q25_pitch', 'q75_pitch', 'iqr_pitch', 
        'MFCC_1', 'MFCC_2', 'MFCC_3', 'MFCC_4', 'MFCC_5', 'MFCC_6', 'MFCC_7', 'MFCC_8', 'MFCC_9', 'MFCC_10',
        'MFCC_11', 'MFCC_12', 'MFCC_13', 'MFCC_14', 'MFCC_15', 'MFCC_16', 'MFCC_17', 'MFCC_18', 'MFCC_19', 'MFCC_20'],index=dfs_CETUC.index)
dfs_CETUC_norm['class'] = dfs_CETUC['Gender_x']
dfs_CETUC_norm

X_cetuc = dfs_CETUC_norm.iloc[:,:-1]
y_cetuc = dfs_CETUC_norm.iloc[:,-1]

print(X_cetuc.shape, y_cetuc.shape)
dfs_CETUC_norm.head()
# Out:
# (100997, 44) (100997,)
#        nobs      mean      skew  kurtosis  ...   MFCC_18   MFCC_19   MFCC_20  class
# 0  0.141414  0.131329  0.417506  0.022868  ...  0.294942  0.338911  0.283948      0
# 1  0.090909  0.249093  0.423483  0.047595  ...  0.773780  0.739221  0.636758      0
# 2  0.191919  0.120077  0.511584  0.041398  ...  0.644729  0.632640  0.541401      1
# 3  0.151515  0.145642  0.472750  0.028083  ...  0.713893  0.591275  0.584856      0
# 4  0.141414  0.143581  0.506598  0.037618  ...  0.315026  0.342287  0.486634      1
#
# [5 rows x 45 columns]

# %% [markdown]
# ## Dataset Change Gender (síntese via PRAAT)

# %%
#features bruno (cetuc)
df_test_change_SER_1 = pd.read_csv('bruno_test_change_Features_data.csv')
df_test_change_SER_2 = pd.read_csv('bruno_test_change_F0_data.csv')
df_test_change_SER_3 = pd.read_csv('bruno_test_change_MFCCs_data.csv')
df_test_change_SER_1_2 =  pd.merge(df_test_change_SER_1, df_test_change_SER_2, on=['FileName'], how='inner')
df_test_change_SER_C = pd.merge(df_test_change_SER_1_2, df_test_change_SER_3, on=['FileName'], how='inner')
df_test_change_SER_C
# Out:
#                                  FileName  nobs  ...   MFCC_19   MFCC_20
# 0    00b08a110b41ba87a3f3b78b1962a4e0.wav     9  ... -5.148062  1.376607
# 1    0117119dc3b53998f0a1ae38d104da5f.wav     9  ... -4.353105 -3.329003
# 2    019bf5b13a1de447f8e107ba66039fd3.wav    11  ... -0.702231  3.767364
# 3    01c8a7058826eb543c3ff61fa66478b9.wav    16  ... -4.870405 -5.242540
# 4    02b6acc8aa673a4cf355165ca4ee99f4.wav    14  ... -4.258274  0.259571
# ..                                    ...   ...  ...       ...       ...
# 436  fe1717406c79c1a906670459fd59ced5.wav    20  ...  2.083612  4.763658
# 437  fe4af5be65ba45838337290f124f2d7c.wav    18  ... -6.375029  3.438993
# 438  fe7a106973df7f51ac9738e4c738cd65.wav     9  ... -1.716247 -1.653648
# 439  ff39e660a411228c78ebc1d42b3b2904.wav    35  ... -4.287939  8.752218
# 440  fff5f2de5207db967286ea70a5d2513a.wav     8  ... -5.009020  1.702017
#
# [441 rows x 45 columns]

# %%
df_change_gender_prosodic = pd.read_csv('change_gender_prosodic_features.csv').sort_values(by='sound_filepath')

df_change_SER_C = df_test_change_SER_C

df_change_SER_C['sound_filepath'] = "train_genero_convertido/"+df_change_SER_C['FileName'] 
df_change_SER_C = df_change_SER_C.drop(['FileName'], axis=1)

# %%
df_change_gender_prosodic_trimmed = df_change_gender_prosodic[['sound_filepath', 'min_intensity', 'max_intensity', 'mean_intensity', 'stddev_intensity',
'min_pitch', 'max_pitch', 'mean_pitch', 'stddev_pitch']]

# %%
#merge
df_change_gender_SER = df_change_gender_prosodic_trimmed
df_change_gender_SER = pd.merge(df_change_gender_SER, df_change_SER_C, on=['sound_filepath'], how='inner')
df_change_gender_SER
# Out:
#                                         sound_filepath  ...   MFCC_20
# 0    train_genero_convertido/bfamcv01_segment168_no...  ...  3.320484
# 1    train_genero_convertido/bfamcv01_segment170_no...  ... -3.746063
# 2    train_genero_convertido/bfamcv01_segment191_no...  ... -1.765121
# 3    train_genero_convertido/bfamcv01_segment200_no...  ... -0.481428
# 4    train_genero_convertido/bfamcv02_segment110_no...  ... -2.608916
# ..                                                 ...  ...       ...
# 128  train_genero_convertido/bpubdl10_segment88_non...  ... -5.876917
# 129  train_genero_convertido/bpubdl10_segment89_non...  ... -2.137917
# 130  train_genero_convertido/bpubdl11_segment369_no...  ... -2.806240
# 131  train_genero_convertido/bpubdl11_segment375_no...  ... -6.718508
# 132  train_genero_convertido/bpubmn01_segment81_non...  ... -6.309799
#
# [133 rows x 53 columns]

# %%
# df_change_gender_SER['sound_filepath'].str.contains('-male', regex=False)
df_change_gender_SER.loc[df_change_gender_SER['sound_filepath'].str.contains('-male', regex=False), 'label'] = 'non-neutral-female'
df_change_gender_SER.loc[df_change_gender_SER['sound_filepath'].str.contains('-female', regex=False), 'label'] = 'non-neutral-male'
df_change_gender_SER.groupby('label').size()
# Out:
# label
# non-neutral-female    45
# non-neutral-male      88
# dtype: int64

# %% [markdown]
# #DATASET SER

# %%
df_prosodic = pd.read_csv('prosodic_features.csv').sort_values(by='sound_filepath')
#df_wav2vec = pd.read_csv('wav2vec_features.csv').sort_values(by='sound_filepath')

# %%
df_prosodic_trimmed = df_prosodic[['label', 'sound_filepath', 'min_intensity', 'max_intensity', 'mean_intensity', 'stddev_intensity',
'min_pitch', 'max_pitch', 'mean_pitch', 'stddev_pitch']]

# %%
#SER com features CETUC
df_SER_1 = pd.read_csv('SER_Features_data.csv')
df_SER_2 = pd.read_csv('SER_F0_data.csv')
df_SER_3 = pd.read_csv('SER_MFCCs_data.csv')
df_SER_1_2 =  pd.merge(df_SER_1, df_SER_2, on=['FileName'], how='inner')
df_SER_C = pd.merge(df_SER_1_2, df_SER_3, on=['FileName'], how='inner')
df_SER_C['sound_filepath'] = "train/"+df_SER_C['FileName'] 
df_SER_C = df_SER_C.drop(['FileName'], axis=1)

#merge
df_SER = df_prosodic_trimmed
df_SER = pd.merge(df_SER, df_SER_C, on=['sound_filepath'], how='inner')
df_SER
# Out:
#                 label  ...   MFCC_20
# 0             neutral  ...  0.175128
# 1    non-neutral-male  ... -3.164199
# 2    non-neutral-male  ... -8.873728
# 3             neutral  ... -6.806720
# 4             neutral  ...  5.107391
# ..                ...  ...       ...
# 620           neutral  ...  0.289649
# 621           neutral  ... -2.202239
# 622           neutral  ... -2.702257
# 623           neutral  ... -1.651545
# 624           neutral  ... -1.053726
#
# [625 rows x 54 columns]

# %%
# não está balanceado
df_SER.groupby('label').size()
# Out:
# label
# neutral               491
# non-neutral-female     89
# non-neutral-male       45
# dtype: int64

# %%
df_change_gender_SER['label']
# Out:
# 0      non-neutral-female
# 1      non-neutral-female
# 2      non-neutral-female
# 3      non-neutral-female
# 4        non-neutral-male
#               ...
# 128      non-neutral-male
# 129      non-neutral-male
# 130      non-neutral-male
# 131      non-neutral-male
# 132      non-neutral-male
# Name: label, Length: 133, dtype: object

# %%
df_SER_2 = pd.concat([df_SER, df_change_gender_SER], ignore_index=True)
df_SER_2
# Out:
#                 label  ...   MFCC_20
# 0             neutral  ...  0.175128
# 1    non-neutral-male  ... -3.164199
# 2    non-neutral-male  ... -8.873728
# 3             neutral  ... -6.806720
# 4             neutral  ...  5.107391
# ..                ...  ...       ...
# 753  non-neutral-male  ... -5.876917
# 754  non-neutral-male  ... -2.137917
# 755  non-neutral-male  ... -2.806240
# 756  non-neutral-male  ... -6.718508
# 757  non-neutral-male  ... -6.309799
#
# [758 rows x 54 columns]

# %%
df_SER_2 = df_SER_2.drop(['sound_filepath'], axis=1)
df_SER_2
# Out:
#                 label  min_intensity  ...   MFCC_19   MFCC_20
# 0             neutral      39.708540  ...  1.331733  0.175128
# 1    non-neutral-male      40.001809  ... -2.860403 -3.164199
# 2    non-neutral-male      54.215080  ... -2.703447 -8.873728
# 3             neutral      41.921520  ... -2.941802 -6.806720
# 4             neutral      40.513441  ...  2.160623  5.107391
# ..                ...            ...  ...       ...       ...
# 753  non-neutral-male      36.088194  ...  1.325925 -5.876917
# 754  non-neutral-male      41.105589  ...  0.997487 -2.137917
# 755  non-neutral-male      26.910711  ... -6.958844 -2.806240
# 756  non-neutral-male      27.821632  ... -0.855823 -6.718508
# 757  non-neutral-male      41.950522  ... -3.783278 -6.309799
#
# [758 rows x 53 columns]

# %%
#one hot encoder
class_encoder = LabelBinarizer()
class_encoder.fit(df_SER_2['label'])
transformed = class_encoder.transform(df_SER_2['label'])
ohe_df = pd.DataFrame(transformed)

ohe_df.shape
# Out:
# (758, 3)

# %%
#df_SER_OH = pd.concat([df_SER_bal, ohe_df], axis=1).drop(['label_x'], axis=1).drop(['label_y'], axis=1)

df_SER_OH = df_SER_2.merge(ohe_df, left_index=True, right_index=True).drop(['label'], axis=1)
df_SER_OH
# Out:
#      min_intensity  max_intensity  mean_intensity  ...  0  1  2
# 0        39.708540      77.218046       54.882812  ...  1  0  0
# 1        40.001809      80.188905       65.918816  ...  0  0  1
# 2        54.215080      82.647111       73.301110  ...  0  0  1
# 3        41.921520      80.672787       65.547409  ...  1  0  0
# 4        40.513441      79.816216       61.535998  ...  1  0  0
# ..             ...            ...             ...  ... .. .. ..
# 753      36.088194      71.204271       56.436351  ...  0  0  1
# 754      41.105589      87.188165       66.456705  ...  0  0  1
# 755      26.910711      68.006774       48.460863  ...  0  0  1
# 756      27.821632      67.072296       51.531330  ...  0  0  1
# 757      41.950522      80.711836       60.492487  ...  0  0  1
#
# [758 rows x 55 columns]

# %%
import numpy as np

X = scaler.fit_transform(df_SER_OH.iloc[:, :-3].values)
print(X.shape)
y = df_SER_OH.iloc[:,-3:]
print(y.shape)
y_multi = df_SER.label.to_list()
X_SER = X
y_SER = np.array(y)

df_SER_OH.head()
# Out:
# (758, 52)
# (758, 3)
#    min_intensity  max_intensity  mean_intensity  ...  0  1  2
# 0      39.708540      77.218046       54.882812  ...  1  0  0
# 1      40.001809      80.188905       65.918816  ...  0  0  1
# 2      54.215080      82.647111       73.301110  ...  0  0  1
# 3      41.921520      80.672787       65.547409  ...  1  0  0
# 4      40.513441      79.816216       61.535998  ...  1  0  0
#
# [5 rows x 55 columns]

# %% [markdown]
# #MULTI TASK TRANSFER LEARNING

# %%
import numpy as np
from keras import Model, layers
from keras.layers import Dense, Input
from matplotlib import pyplot
from sklearn.metrics import classification_report

from sklearn.metrics import  f1_score

# K-fold Cross Validation model evaluation
from sklearn.model_selection import KFold
kfold = KFold(n_splits=5, shuffle=True)

fold_no = 1
f1_per_fold = []
acc_per_fold = []
loss_per_fold = []

for train, test in kfold.split(X_SER, y_SER):
  X_ser_train_824 = X_SER[train, :-44]
  X_ser_train_44 = X_SER[train, -44:]
  X_ser_test_824 = X_SER[test, :-44]
  X_ser_test_44 = X_SER[test, -44:]

  y_ser_train = y_SER[train]
  y_ser_test = y_SER[test]

  input_layer_ser = Input(shape=(8,), name='ser_input')
  input_layer_cetuc = Input(shape=(44,), name='cetuc_input')

  layer_1_ser = Dense(10, kernel_initializer='normal', activation='relu', name='ser_layer_1')(input_layer_ser)
  layer_1_cetuc = Dense(10, kernel_initializer='normal', activation='relu', name='cetuc_layer_1')(input_layer_cetuc)

  merged = layers.concatenate([layer_1_ser, layer_1_cetuc])

  shared_layer = Dense(100, activation='relu', name='shared_layer')(merged)

  output_layer_ser = Dense(3, kernel_initializer='normal', activation="sigmoid", name='ser_output')(shared_layer)
  output_layer_cetuc = Dense(1, kernel_initializer='normal', activation="relu", name='cetuc_output')(shared_layer)
 
  model = Model(inputs=[input_layer_ser, input_layer_cetuc], outputs=[output_layer_ser, output_layer_cetuc])
  model.compile(loss='mean_squared_error', optimizer='adam')

  history = model.fit([X_ser_train_824, X_ser_train_44], y_ser_train, epochs=300, batch_size=100, validation_data=([X_ser_test_824, X_ser_test_44], y_ser_test), verbose=1, shuffle=False)

  #fscore
  y_pred = model.predict([X_ser_test_824, X_ser_test_44], batch_size=64, verbose=1)
  y_pred_c = np.argmax(y_pred[0], axis=1)
  y_test_c = np.argmax(y_ser_test, axis=1)
  print(classification_report(y_test_c, y_pred_c, zero_division=0))
  _val_f1 = f1_score(y_test_c, y_pred_c, average='macro', zero_division=0)
  print ("val_f1: ", _val_f1)
  f1_per_fold.append(_val_f1)

  scores = model.evaluate([X_ser_test_824, X_ser_test_44], y_ser_test, verbose=1)
  print(model.metrics_names, scores)
  print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
  acc_per_fold.append(scores[1] * 100)
  loss_per_fold.append(scores[0])

  # Increase fold number
  fold_no = fold_no + 1

# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - F1-Macro: {f1_per_fold[i]} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> F1-Macro: {np.mean(f1_per_fold)} (+- {np.std(f1_per_fold)})')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# Epoch 1/300
# 7/7 [==============================] - 1s 45ms/step - loss: 0.5663 - ser_output_loss: 0.2495 - cetuc_output_loss: 0.3168 - val_loss: 0.5370 - val_ser_output_loss: 0.2466 - val_cetuc_output_loss: 0.2904
# Epoch 2/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5208 - ser_output_loss: 0.2457 - cetuc_output_loss: 0.2750 - val_loss: 0.4905 - val_ser_output_loss: 0.2420 - val_cetuc_output_loss: 0.2485
# Epoch 3/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4775 - ser_output_loss: 0.2406 - cetuc_output_loss: 0.2369 - val_loss: 0.4580 - val_ser_output_loss: 0.2344 - val_cetuc_output_loss: 0.2236
# Epoch 4/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4579 - ser_output_loss: 0.2326 - cetuc_output_loss: 0.2252 - val_loss: 0.4555 - val_ser_output_loss: 0.2251 - val_cetuc_output_loss: 0.2304
# Epoch 5/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4545 - ser_output_loss: 0.2244 - cetuc_output_loss: 0.2301 - val_loss: 0.4446 - val_ser_output_loss: 0.2187 - val_cetuc_output_loss: 0.2260
# Epoch 6/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4434 - ser_output_loss: 0.2189 - cetuc_output_loss: 0.2245 - val_loss: 0.4364 - val_ser_output_loss: 0.2133 - val_cetuc_output_loss: 0.2231
# Epoch 7/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4370 - ser_output_loss: 0.2137 - cetuc_output_loss: 0.2233 - val_loss: 0.4294 - val_ser_output_loss: 0.2063 - val_cetuc_output_loss: 0.2231
# Epoch 8/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4302 - ser_output_loss: 0.2069 - cetuc_output_loss: 0.2233 - val_loss: 0.4218 - val_ser_output_loss: 0.1985 - val_cetuc_output_loss: 0.2233
# Epoch 9/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4237 - ser_output_loss: 0.2001 - cetuc_output_loss: 0.2236 - val_loss: 0.4154 - val_ser_output_loss: 0.1920 - val_cetuc_output_loss: 0.2234
# Epoch 10/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4179 - ser_output_loss: 0.1946 - cetuc_output_loss: 0.2233 - val_loss: 0.4100 - val_ser_output_loss: 0.1870 - val_cetuc_output_loss: 0.2230
# Epoch 11/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4135 - ser_output_loss: 0.1903 - cetuc_output_loss: 0.2231 - val_loss: 0.4058 - val_ser_output_loss: 0.1828 - val_cetuc_output_loss: 0.2230
# Epoch 12/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4100 - ser_output_loss: 0.1869 - cetuc_output_loss: 0.2231 - val_loss: 0.4029 - val_ser_output_loss: 0.1799 - val_cetuc_output_loss: 0.2230
# Epoch 13/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4076 - ser_output_loss: 0.1845 - cetuc_output_loss: 0.2231 - val_loss: 0.4011 - val_ser_output_loss: 0.1782 - val_cetuc_output_loss: 0.2229
# Epoch 14/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4061 - ser_output_loss: 0.1831 - cetuc_output_loss: 0.2230 - val_loss: 0.3999 - val_ser_output_loss: 0.1770 - val_cetuc_output_loss: 0.2229
# Epoch 15/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4051 - ser_output_loss: 0.1821 - cetuc_output_loss: 0.2230 - val_loss: 0.3992 - val_ser_output_loss: 0.1764 - val_cetuc_output_loss: 0.2228
# Epoch 16/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4045 - ser_output_loss: 0.1816 - cetuc_output_loss: 0.2230 - val_loss: 0.3988 - val_ser_output_loss: 0.1760 - val_cetuc_output_loss: 0.2228
# Epoch 17/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4042 - ser_output_loss: 0.1812 - cetuc_output_loss: 0.2229 - val_loss: 0.3986 - val_ser_output_loss: 0.1758 - val_cetuc_output_loss: 0.2228
# Epoch 18/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4039 - ser_output_loss: 0.1810 - cetuc_output_loss: 0.2229 - val_loss: 0.3984 - val_ser_output_loss: 0.1756 - val_cetuc_output_loss: 0.2228
# Epoch 19/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4037 - ser_output_loss: 0.1809 - cetuc_output_loss: 0.2229 - val_loss: 0.3983 - val_ser_output_loss: 0.1755 - val_cetuc_output_loss: 0.2227
# Epoch 20/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4036 - ser_output_loss: 0.1807 - cetuc_output_loss: 0.2229 - val_loss: 0.3981 - val_ser_output_loss: 0.1754 - val_cetuc_output_loss: 0.2227
# Epoch 21/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4034 - ser_output_loss: 0.1806 - cetuc_output_loss: 0.2228 - val_loss: 0.3980 - val_ser_output_loss: 0.1753 - val_cetuc_output_loss: 0.2227
# Epoch 22/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4033 - ser_output_loss: 0.1805 - cetuc_output_loss: 0.2228 - val_loss: 0.3979 - val_ser_output_loss: 0.1752 - val_cetuc_output_loss: 0.2227
# Epoch 23/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4032 - ser_output_loss: 0.1804 - cetuc_output_loss: 0.2228 - val_loss: 0.3978 - val_ser_output_loss: 0.1751 - val_cetuc_output_loss: 0.2227
# Epoch 24/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4030 - ser_output_loss: 0.1803 - cetuc_output_loss: 0.2227 - val_loss: 0.3976 - val_ser_output_loss: 0.1750 - val_cetuc_output_loss: 0.2226
# Epoch 25/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4029 - ser_output_loss: 0.1802 - cetuc_output_loss: 0.2227 - val_loss: 0.3975 - val_ser_output_loss: 0.1749 - val_cetuc_output_loss: 0.2226
# Epoch 26/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4027 - ser_output_loss: 0.1800 - cetuc_output_loss: 0.2227 - val_loss: 0.3973 - val_ser_output_loss: 0.1748 - val_cetuc_output_loss: 0.2226
# Epoch 27/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4025 - ser_output_loss: 0.1799 - cetuc_output_loss: 0.2226 - val_loss: 0.3972 - val_ser_output_loss: 0.1746 - val_cetuc_output_loss: 0.2226
# Epoch 28/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4024 - ser_output_loss: 0.1797 - cetuc_output_loss: 0.2226 - val_loss: 0.3970 - val_ser_output_loss: 0.1745 - val_cetuc_output_loss: 0.2226
# Epoch 29/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4022 - ser_output_loss: 0.1796 - cetuc_output_loss: 0.2226 - val_loss: 0.3968 - val_ser_output_loss: 0.1743 - val_cetuc_output_loss: 0.2225
# Epoch 30/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4020 - ser_output_loss: 0.1794 - cetuc_output_loss: 0.2226 - val_loss: 0.3967 - val_ser_output_loss: 0.1741 - val_cetuc_output_loss: 0.2225
# Epoch 31/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4018 - ser_output_loss: 0.1792 - cetuc_output_loss: 0.2226 - val_loss: 0.3965 - val_ser_output_loss: 0.1739 - val_cetuc_output_loss: 0.2225
# Epoch 32/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4016 - ser_output_loss: 0.1790 - cetuc_output_loss: 0.2225 - val_loss: 0.3963 - val_ser_output_loss: 0.1738 - val_cetuc_output_loss: 0.2225
# Epoch 33/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4014 - ser_output_loss: 0.1789 - cetuc_output_loss: 0.2225 - val_loss: 0.3961 - val_ser_output_loss: 0.1736 - val_cetuc_output_loss: 0.2225
# Epoch 34/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4012 - ser_output_loss: 0.1787 - cetuc_output_loss: 0.2225 - val_loss: 0.3959 - val_ser_output_loss: 0.1734 - val_cetuc_output_loss: 0.2225
# Epoch 35/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4010 - ser_output_loss: 0.1785 - cetuc_output_loss: 0.2225 - val_loss: 0.3957 - val_ser_output_loss: 0.1732 - val_cetuc_output_loss: 0.2225
# Epoch 36/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4008 - ser_output_loss: 0.1783 - cetuc_output_loss: 0.2225 - val_loss: 0.3955 - val_ser_output_loss: 0.1730 - val_cetuc_output_loss: 0.2225
# Epoch 37/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4006 - ser_output_loss: 0.1780 - cetuc_output_loss: 0.2225 - val_loss: 0.3953 - val_ser_output_loss: 0.1728 - val_cetuc_output_loss: 0.2225
# Epoch 38/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4003 - ser_output_loss: 0.1778 - cetuc_output_loss: 0.2225 - val_loss: 0.3950 - val_ser_output_loss: 0.1725 - val_cetuc_output_loss: 0.2225
# Epoch 39/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4001 - ser_output_loss: 0.1776 - cetuc_output_loss: 0.2225 - val_loss: 0.3948 - val_ser_output_loss: 0.1723 - val_cetuc_output_loss: 0.2225
# Epoch 40/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3998 - ser_output_loss: 0.1773 - cetuc_output_loss: 0.2225 - val_loss: 0.3945 - val_ser_output_loss: 0.1720 - val_cetuc_output_loss: 0.2225
# Epoch 41/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3995 - ser_output_loss: 0.1770 - cetuc_output_loss: 0.2225 - val_loss: 0.3943 - val_ser_output_loss: 0.1718 - val_cetuc_output_loss: 0.2225
# Epoch 42/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3992 - ser_output_loss: 0.1767 - cetuc_output_loss: 0.2225 - val_loss: 0.3940 - val_ser_output_loss: 0.1715 - val_cetuc_output_loss: 0.2225
# Epoch 43/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3989 - ser_output_loss: 0.1764 - cetuc_output_loss: 0.2225 - val_loss: 0.3937 - val_ser_output_loss: 0.1712 - val_cetuc_output_loss: 0.2225
# Epoch 44/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3986 - ser_output_loss: 0.1761 - cetuc_output_loss: 0.2225 - val_loss: 0.3933 - val_ser_output_loss: 0.1708 - val_cetuc_output_loss: 0.2225
# Epoch 45/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3982 - ser_output_loss: 0.1757 - cetuc_output_loss: 0.2225 - val_loss: 0.3929 - val_ser_output_loss: 0.1704 - val_cetuc_output_loss: 0.2225
# Epoch 46/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3978 - ser_output_loss: 0.1753 - cetuc_output_loss: 0.2225 - val_loss: 0.3925 - val_ser_output_loss: 0.1700 - val_cetuc_output_loss: 0.2225
# Epoch 47/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3973 - ser_output_loss: 0.1748 - cetuc_output_loss: 0.2225 - val_loss: 0.3921 - val_ser_output_loss: 0.1696 - val_cetuc_output_loss: 0.2225
# Epoch 48/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3969 - ser_output_loss: 0.1744 - cetuc_output_loss: 0.2225 - val_loss: 0.3917 - val_ser_output_loss: 0.1692 - val_cetuc_output_loss: 0.2225
# Epoch 49/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3964 - ser_output_loss: 0.1739 - cetuc_output_loss: 0.2225 - val_loss: 0.3912 - val_ser_output_loss: 0.1687 - val_cetuc_output_loss: 0.2225
# Epoch 50/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3959 - ser_output_loss: 0.1734 - cetuc_output_loss: 0.2225 - val_loss: 0.3907 - val_ser_output_loss: 0.1682 - val_cetuc_output_loss: 0.2225
# Epoch 51/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3953 - ser_output_loss: 0.1729 - cetuc_output_loss: 0.2225 - val_loss: 0.3901 - val_ser_output_loss: 0.1677 - val_cetuc_output_loss: 0.2225
# Epoch 52/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3947 - ser_output_loss: 0.1722 - cetuc_output_loss: 0.2225 - val_loss: 0.3895 - val_ser_output_loss: 0.1671 - val_cetuc_output_loss: 0.2225
# Epoch 53/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3940 - ser_output_loss: 0.1716 - cetuc_output_loss: 0.2224 - val_loss: 0.3889 - val_ser_output_loss: 0.1664 - val_cetuc_output_loss: 0.2224
# Epoch 54/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3933 - ser_output_loss: 0.1709 - cetuc_output_loss: 0.2224 - val_loss: 0.3882 - val_ser_output_loss: 0.1657 - val_cetuc_output_loss: 0.2224
# Epoch 55/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3926 - ser_output_loss: 0.1701 - cetuc_output_loss: 0.2224 - val_loss: 0.3874 - val_ser_output_loss: 0.1650 - val_cetuc_output_loss: 0.2224
# Epoch 56/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3917 - ser_output_loss: 0.1693 - cetuc_output_loss: 0.2224 - val_loss: 0.3866 - val_ser_output_loss: 0.1641 - val_cetuc_output_loss: 0.2224
# Epoch 57/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3908 - ser_output_loss: 0.1684 - cetuc_output_loss: 0.2224 - val_loss: 0.3857 - val_ser_output_loss: 0.1633 - val_cetuc_output_loss: 0.2224
# Epoch 58/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3898 - ser_output_loss: 0.1674 - cetuc_output_loss: 0.2224 - val_loss: 0.3847 - val_ser_output_loss: 0.1623 - val_cetuc_output_loss: 0.2224
# Epoch 59/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3887 - ser_output_loss: 0.1663 - cetuc_output_loss: 0.2224 - val_loss: 0.3837 - val_ser_output_loss: 0.1613 - val_cetuc_output_loss: 0.2224
# Epoch 60/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3877 - ser_output_loss: 0.1652 - cetuc_output_loss: 0.2224 - val_loss: 0.3827 - val_ser_output_loss: 0.1603 - val_cetuc_output_loss: 0.2224
# Epoch 61/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3866 - ser_output_loss: 0.1641 - cetuc_output_loss: 0.2224 - val_loss: 0.3816 - val_ser_output_loss: 0.1591 - val_cetuc_output_loss: 0.2224
# Epoch 62/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3853 - ser_output_loss: 0.1629 - cetuc_output_loss: 0.2224 - val_loss: 0.3803 - val_ser_output_loss: 0.1579 - val_cetuc_output_loss: 0.2224
# Epoch 63/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3840 - ser_output_loss: 0.1616 - cetuc_output_loss: 0.2224 - val_loss: 0.3791 - val_ser_output_loss: 0.1567 - val_cetuc_output_loss: 0.2224
# Epoch 64/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3826 - ser_output_loss: 0.1602 - cetuc_output_loss: 0.2224 - val_loss: 0.3777 - val_ser_output_loss: 0.1553 - val_cetuc_output_loss: 0.2224
# Epoch 65/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3811 - ser_output_loss: 0.1587 - cetuc_output_loss: 0.2224 - val_loss: 0.3763 - val_ser_output_loss: 0.1539 - val_cetuc_output_loss: 0.2224
# Epoch 66/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3796 - ser_output_loss: 0.1572 - cetuc_output_loss: 0.2224 - val_loss: 0.3749 - val_ser_output_loss: 0.1525 - val_cetuc_output_loss: 0.2224
# Epoch 67/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3781 - ser_output_loss: 0.1557 - cetuc_output_loss: 0.2224 - val_loss: 0.3734 - val_ser_output_loss: 0.1510 - val_cetuc_output_loss: 0.2224
# Epoch 68/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3765 - ser_output_loss: 0.1541 - cetuc_output_loss: 0.2224 - val_loss: 0.3720 - val_ser_output_loss: 0.1495 - val_cetuc_output_loss: 0.2224
# Epoch 69/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3750 - ser_output_loss: 0.1526 - cetuc_output_loss: 0.2224 - val_loss: 0.3705 - val_ser_output_loss: 0.1481 - val_cetuc_output_loss: 0.2224
# Epoch 70/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3735 - ser_output_loss: 0.1510 - cetuc_output_loss: 0.2224 - val_loss: 0.3690 - val_ser_output_loss: 0.1466 - val_cetuc_output_loss: 0.2224
# Epoch 71/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3718 - ser_output_loss: 0.1494 - cetuc_output_loss: 0.2224 - val_loss: 0.3675 - val_ser_output_loss: 0.1451 - val_cetuc_output_loss: 0.2224
# Epoch 72/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3702 - ser_output_loss: 0.1478 - cetuc_output_loss: 0.2224 - val_loss: 0.3660 - val_ser_output_loss: 0.1436 - val_cetuc_output_loss: 0.2224
# Epoch 73/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3687 - ser_output_loss: 0.1463 - cetuc_output_loss: 0.2224 - val_loss: 0.3645 - val_ser_output_loss: 0.1421 - val_cetuc_output_loss: 0.2224
# Epoch 74/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3672 - ser_output_loss: 0.1448 - cetuc_output_loss: 0.2224 - val_loss: 0.3631 - val_ser_output_loss: 0.1407 - val_cetuc_output_loss: 0.2224
# Epoch 75/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3656 - ser_output_loss: 0.1432 - cetuc_output_loss: 0.2224 - val_loss: 0.3616 - val_ser_output_loss: 0.1392 - val_cetuc_output_loss: 0.2224
# Epoch 76/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3641 - ser_output_loss: 0.1417 - cetuc_output_loss: 0.2225 - val_loss: 0.3602 - val_ser_output_loss: 0.1378 - val_cetuc_output_loss: 0.2224
# Epoch 77/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3626 - ser_output_loss: 0.1402 - cetuc_output_loss: 0.2224 - val_loss: 0.3589 - val_ser_output_loss: 0.1364 - val_cetuc_output_loss: 0.2225
# Epoch 78/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3612 - ser_output_loss: 0.1388 - cetuc_output_loss: 0.2225 - val_loss: 0.3575 - val_ser_output_loss: 0.1351 - val_cetuc_output_loss: 0.2224
# Epoch 79/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3599 - ser_output_loss: 0.1374 - cetuc_output_loss: 0.2225 - val_loss: 0.3563 - val_ser_output_loss: 0.1338 - val_cetuc_output_loss: 0.2225
# Epoch 80/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3586 - ser_output_loss: 0.1361 - cetuc_output_loss: 0.2225 - val_loss: 0.3552 - val_ser_output_loss: 0.1326 - val_cetuc_output_loss: 0.2227
# Epoch 81/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3574 - ser_output_loss: 0.1348 - cetuc_output_loss: 0.2226 - val_loss: 0.3538 - val_ser_output_loss: 0.1314 - val_cetuc_output_loss: 0.2224
# Epoch 82/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3561 - ser_output_loss: 0.1336 - cetuc_output_loss: 0.2225 - val_loss: 0.3528 - val_ser_output_loss: 0.1302 - val_cetuc_output_loss: 0.2225
# Epoch 83/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3549 - ser_output_loss: 0.1324 - cetuc_output_loss: 0.2225 - val_loss: 0.3519 - val_ser_output_loss: 0.1291 - val_cetuc_output_loss: 0.2229
# Epoch 84/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3539 - ser_output_loss: 0.1312 - cetuc_output_loss: 0.2227 - val_loss: 0.3505 - val_ser_output_loss: 0.1280 - val_cetuc_output_loss: 0.2225
# Epoch 85/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3528 - ser_output_loss: 0.1302 - cetuc_output_loss: 0.2226 - val_loss: 0.3495 - val_ser_output_loss: 0.1270 - val_cetuc_output_loss: 0.2225
# Epoch 86/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3517 - ser_output_loss: 0.1291 - cetuc_output_loss: 0.2225 - val_loss: 0.3490 - val_ser_output_loss: 0.1261 - val_cetuc_output_loss: 0.2229
# Epoch 87/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3509 - ser_output_loss: 0.1282 - cetuc_output_loss: 0.2227 - val_loss: 0.3478 - val_ser_output_loss: 0.1253 - val_cetuc_output_loss: 0.2226
# Epoch 88/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3499 - ser_output_loss: 0.1273 - cetuc_output_loss: 0.2226 - val_loss: 0.3469 - val_ser_output_loss: 0.1244 - val_cetuc_output_loss: 0.2225
# Epoch 89/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3489 - ser_output_loss: 0.1264 - cetuc_output_loss: 0.2225 - val_loss: 0.3463 - val_ser_output_loss: 0.1236 - val_cetuc_output_loss: 0.2226
# Epoch 90/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3481 - ser_output_loss: 0.1255 - cetuc_output_loss: 0.2226 - val_loss: 0.3454 - val_ser_output_loss: 0.1229 - val_cetuc_output_loss: 0.2225
# Epoch 91/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3473 - ser_output_loss: 0.1248 - cetuc_output_loss: 0.2225 - val_loss: 0.3447 - val_ser_output_loss: 0.1222 - val_cetuc_output_loss: 0.2225
# Epoch 92/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3465 - ser_output_loss: 0.1240 - cetuc_output_loss: 0.2225 - val_loss: 0.3440 - val_ser_output_loss: 0.1215 - val_cetuc_output_loss: 0.2225
# Epoch 93/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3457 - ser_output_loss: 0.1233 - cetuc_output_loss: 0.2225 - val_loss: 0.3433 - val_ser_output_loss: 0.1209 - val_cetuc_output_loss: 0.2225
# Epoch 94/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3450 - ser_output_loss: 0.1226 - cetuc_output_loss: 0.2225 - val_loss: 0.3427 - val_ser_output_loss: 0.1202 - val_cetuc_output_loss: 0.2225
# Epoch 95/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3443 - ser_output_loss: 0.1218 - cetuc_output_loss: 0.2225 - val_loss: 0.3420 - val_ser_output_loss: 0.1196 - val_cetuc_output_loss: 0.2225
# Epoch 96/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3436 - ser_output_loss: 0.1212 - cetuc_output_loss: 0.2225 - val_loss: 0.3415 - val_ser_output_loss: 0.1190 - val_cetuc_output_loss: 0.2225
# Epoch 97/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3430 - ser_output_loss: 0.1205 - cetuc_output_loss: 0.2225 - val_loss: 0.3409 - val_ser_output_loss: 0.1184 - val_cetuc_output_loss: 0.2225
# Epoch 98/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3423 - ser_output_loss: 0.1198 - cetuc_output_loss: 0.2225 - val_loss: 0.3403 - val_ser_output_loss: 0.1178 - val_cetuc_output_loss: 0.2225
# Epoch 99/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3417 - ser_output_loss: 0.1191 - cetuc_output_loss: 0.2225 - val_loss: 0.3398 - val_ser_output_loss: 0.1173 - val_cetuc_output_loss: 0.2225
# Epoch 100/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3410 - ser_output_loss: 0.1185 - cetuc_output_loss: 0.2225 - val_loss: 0.3393 - val_ser_output_loss: 0.1167 - val_cetuc_output_loss: 0.2226
# Epoch 101/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3404 - ser_output_loss: 0.1179 - cetuc_output_loss: 0.2225 - val_loss: 0.3387 - val_ser_output_loss: 0.1162 - val_cetuc_output_loss: 0.2225
# Epoch 102/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3398 - ser_output_loss: 0.1173 - cetuc_output_loss: 0.2225 - val_loss: 0.3383 - val_ser_output_loss: 0.1157 - val_cetuc_output_loss: 0.2225
# Epoch 103/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3392 - ser_output_loss: 0.1167 - cetuc_output_loss: 0.2225 - val_loss: 0.3379 - val_ser_output_loss: 0.1152 - val_cetuc_output_loss: 0.2227
# Epoch 104/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3387 - ser_output_loss: 0.1161 - cetuc_output_loss: 0.2226 - val_loss: 0.3372 - val_ser_output_loss: 0.1148 - val_cetuc_output_loss: 0.2224
# Epoch 105/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3381 - ser_output_loss: 0.1156 - cetuc_output_loss: 0.2225 - val_loss: 0.3368 - val_ser_output_loss: 0.1143 - val_cetuc_output_loss: 0.2225
# Epoch 106/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3375 - ser_output_loss: 0.1151 - cetuc_output_loss: 0.2225 - val_loss: 0.3366 - val_ser_output_loss: 0.1139 - val_cetuc_output_loss: 0.2228
# Epoch 107/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3371 - ser_output_loss: 0.1145 - cetuc_output_loss: 0.2226 - val_loss: 0.3359 - val_ser_output_loss: 0.1134 - val_cetuc_output_loss: 0.2225
# Epoch 108/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3365 - ser_output_loss: 0.1140 - cetuc_output_loss: 0.2226 - val_loss: 0.3355 - val_ser_output_loss: 0.1130 - val_cetuc_output_loss: 0.2225
# Epoch 109/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3359 - ser_output_loss: 0.1134 - cetuc_output_loss: 0.2225 - val_loss: 0.3354 - val_ser_output_loss: 0.1126 - val_cetuc_output_loss: 0.2228
# Epoch 110/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3355 - ser_output_loss: 0.1129 - cetuc_output_loss: 0.2226 - val_loss: 0.3347 - val_ser_output_loss: 0.1122 - val_cetuc_output_loss: 0.2225
# Epoch 111/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3350 - ser_output_loss: 0.1124 - cetuc_output_loss: 0.2226 - val_loss: 0.3343 - val_ser_output_loss: 0.1118 - val_cetuc_output_loss: 0.2224
# Epoch 112/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3344 - ser_output_loss: 0.1119 - cetuc_output_loss: 0.2225 - val_loss: 0.3341 - val_ser_output_loss: 0.1114 - val_cetuc_output_loss: 0.2227
# Epoch 113/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3340 - ser_output_loss: 0.1114 - cetuc_output_loss: 0.2226 - val_loss: 0.3336 - val_ser_output_loss: 0.1111 - val_cetuc_output_loss: 0.2225
# Epoch 114/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3336 - ser_output_loss: 0.1110 - cetuc_output_loss: 0.2225 - val_loss: 0.3332 - val_ser_output_loss: 0.1107 - val_cetuc_output_loss: 0.2225
# Epoch 115/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3330 - ser_output_loss: 0.1105 - cetuc_output_loss: 0.2225 - val_loss: 0.3329 - val_ser_output_loss: 0.1103 - val_cetuc_output_loss: 0.2226
# Epoch 116/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3326 - ser_output_loss: 0.1100 - cetuc_output_loss: 0.2225 - val_loss: 0.3325 - val_ser_output_loss: 0.1100 - val_cetuc_output_loss: 0.2225
# Epoch 117/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3321 - ser_output_loss: 0.1096 - cetuc_output_loss: 0.2225 - val_loss: 0.3321 - val_ser_output_loss: 0.1097 - val_cetuc_output_loss: 0.2225
# Epoch 118/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3316 - ser_output_loss: 0.1091 - cetuc_output_loss: 0.2225 - val_loss: 0.3318 - val_ser_output_loss: 0.1093 - val_cetuc_output_loss: 0.2225
# Epoch 119/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3312 - ser_output_loss: 0.1087 - cetuc_output_loss: 0.2225 - val_loss: 0.3315 - val_ser_output_loss: 0.1090 - val_cetuc_output_loss: 0.2225
# Epoch 120/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3308 - ser_output_loss: 0.1083 - cetuc_output_loss: 0.2225 - val_loss: 0.3311 - val_ser_output_loss: 0.1087 - val_cetuc_output_loss: 0.2225
# Epoch 121/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3303 - ser_output_loss: 0.1079 - cetuc_output_loss: 0.2225 - val_loss: 0.3308 - val_ser_output_loss: 0.1083 - val_cetuc_output_loss: 0.2225
# Epoch 122/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3299 - ser_output_loss: 0.1074 - cetuc_output_loss: 0.2225 - val_loss: 0.3305 - val_ser_output_loss: 0.1080 - val_cetuc_output_loss: 0.2224
# Epoch 123/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3295 - ser_output_loss: 0.1070 - cetuc_output_loss: 0.2224 - val_loss: 0.3302 - val_ser_output_loss: 0.1077 - val_cetuc_output_loss: 0.2225
# Epoch 124/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3291 - ser_output_loss: 0.1066 - cetuc_output_loss: 0.2225 - val_loss: 0.3299 - val_ser_output_loss: 0.1075 - val_cetuc_output_loss: 0.2224
# Epoch 125/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3287 - ser_output_loss: 0.1062 - cetuc_output_loss: 0.2225 - val_loss: 0.3296 - val_ser_output_loss: 0.1072 - val_cetuc_output_loss: 0.2224
# Epoch 126/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3283 - ser_output_loss: 0.1058 - cetuc_output_loss: 0.2224 - val_loss: 0.3294 - val_ser_output_loss: 0.1069 - val_cetuc_output_loss: 0.2225
# Epoch 127/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3279 - ser_output_loss: 0.1054 - cetuc_output_loss: 0.2225 - val_loss: 0.3291 - val_ser_output_loss: 0.1066 - val_cetuc_output_loss: 0.2224
# Epoch 128/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3275 - ser_output_loss: 0.1050 - cetuc_output_loss: 0.2224 - val_loss: 0.3288 - val_ser_output_loss: 0.1064 - val_cetuc_output_loss: 0.2224
# Epoch 129/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3271 - ser_output_loss: 0.1047 - cetuc_output_loss: 0.2224 - val_loss: 0.3286 - val_ser_output_loss: 0.1061 - val_cetuc_output_loss: 0.2225
# Epoch 130/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3267 - ser_output_loss: 0.1043 - cetuc_output_loss: 0.2225 - val_loss: 0.3283 - val_ser_output_loss: 0.1059 - val_cetuc_output_loss: 0.2224
# Epoch 131/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3264 - ser_output_loss: 0.1039 - cetuc_output_loss: 0.2224 - val_loss: 0.3281 - val_ser_output_loss: 0.1057 - val_cetuc_output_loss: 0.2224
# Epoch 132/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3260 - ser_output_loss: 0.1036 - cetuc_output_loss: 0.2224 - val_loss: 0.3279 - val_ser_output_loss: 0.1054 - val_cetuc_output_loss: 0.2225
# Epoch 133/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3257 - ser_output_loss: 0.1032 - cetuc_output_loss: 0.2225 - val_loss: 0.3276 - val_ser_output_loss: 0.1052 - val_cetuc_output_loss: 0.2224
# Epoch 134/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3253 - ser_output_loss: 0.1029 - cetuc_output_loss: 0.2224 - val_loss: 0.3274 - val_ser_output_loss: 0.1050 - val_cetuc_output_loss: 0.2224
# Epoch 135/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3250 - ser_output_loss: 0.1025 - cetuc_output_loss: 0.2224 - val_loss: 0.3273 - val_ser_output_loss: 0.1047 - val_cetuc_output_loss: 0.2225
# Epoch 136/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3247 - ser_output_loss: 0.1022 - cetuc_output_loss: 0.2225 - val_loss: 0.3269 - val_ser_output_loss: 0.1045 - val_cetuc_output_loss: 0.2224
# Epoch 137/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3243 - ser_output_loss: 0.1019 - cetuc_output_loss: 0.2224 - val_loss: 0.3267 - val_ser_output_loss: 0.1043 - val_cetuc_output_loss: 0.2224
# Epoch 138/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3240 - ser_output_loss: 0.1016 - cetuc_output_loss: 0.2224 - val_loss: 0.3266 - val_ser_output_loss: 0.1041 - val_cetuc_output_loss: 0.2225
# Epoch 139/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3237 - ser_output_loss: 0.1013 - cetuc_output_loss: 0.2225 - val_loss: 0.3263 - val_ser_output_loss: 0.1038 - val_cetuc_output_loss: 0.2224
# Epoch 140/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3234 - ser_output_loss: 0.1010 - cetuc_output_loss: 0.2225 - val_loss: 0.3260 - val_ser_output_loss: 0.1036 - val_cetuc_output_loss: 0.2224
# Epoch 141/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3231 - ser_output_loss: 0.1007 - cetuc_output_loss: 0.2224 - val_loss: 0.3260 - val_ser_output_loss: 0.1034 - val_cetuc_output_loss: 0.2226
# Epoch 142/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3228 - ser_output_loss: 0.1003 - cetuc_output_loss: 0.2225 - val_loss: 0.3257 - val_ser_output_loss: 0.1032 - val_cetuc_output_loss: 0.2224
# Epoch 143/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3226 - ser_output_loss: 0.1001 - cetuc_output_loss: 0.2225 - val_loss: 0.3254 - val_ser_output_loss: 0.1030 - val_cetuc_output_loss: 0.2224
# Epoch 144/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3222 - ser_output_loss: 0.0998 - cetuc_output_loss: 0.2224 - val_loss: 0.3254 - val_ser_output_loss: 0.1028 - val_cetuc_output_loss: 0.2226
# Epoch 145/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3220 - ser_output_loss: 0.0995 - cetuc_output_loss: 0.2225 - val_loss: 0.3251 - val_ser_output_loss: 0.1026 - val_cetuc_output_loss: 0.2225
# Epoch 146/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3217 - ser_output_loss: 0.0992 - cetuc_output_loss: 0.2225 - val_loss: 0.3249 - val_ser_output_loss: 0.1025 - val_cetuc_output_loss: 0.2224
# Epoch 147/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3214 - ser_output_loss: 0.0990 - cetuc_output_loss: 0.2225 - val_loss: 0.3248 - val_ser_output_loss: 0.1023 - val_cetuc_output_loss: 0.2225
# Epoch 148/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3212 - ser_output_loss: 0.0987 - cetuc_output_loss: 0.2225 - val_loss: 0.3247 - val_ser_output_loss: 0.1021 - val_cetuc_output_loss: 0.2226
# Epoch 149/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3210 - ser_output_loss: 0.0985 - cetuc_output_loss: 0.2225 - val_loss: 0.3244 - val_ser_output_loss: 0.1019 - val_cetuc_output_loss: 0.2225
# Epoch 150/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3207 - ser_output_loss: 0.0982 - cetuc_output_loss: 0.2225 - val_loss: 0.3242 - val_ser_output_loss: 0.1018 - val_cetuc_output_loss: 0.2225
# Epoch 151/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3204 - ser_output_loss: 0.0979 - cetuc_output_loss: 0.2225 - val_loss: 0.3242 - val_ser_output_loss: 0.1016 - val_cetuc_output_loss: 0.2226
# Epoch 152/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3202 - ser_output_loss: 0.0977 - cetuc_output_loss: 0.2225 - val_loss: 0.3240 - val_ser_output_loss: 0.1014 - val_cetuc_output_loss: 0.2226
# Epoch 153/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3200 - ser_output_loss: 0.0975 - cetuc_output_loss: 0.2225 - val_loss: 0.3237 - val_ser_output_loss: 0.1013 - val_cetuc_output_loss: 0.2224
# Epoch 154/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3197 - ser_output_loss: 0.0972 - cetuc_output_loss: 0.2225 - val_loss: 0.3237 - val_ser_output_loss: 0.1011 - val_cetuc_output_loss: 0.2226
# Epoch 155/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3195 - ser_output_loss: 0.0970 - cetuc_output_loss: 0.2225 - val_loss: 0.3236 - val_ser_output_loss: 0.1010 - val_cetuc_output_loss: 0.2226
# Epoch 156/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3193 - ser_output_loss: 0.0968 - cetuc_output_loss: 0.2226 - val_loss: 0.3232 - val_ser_output_loss: 0.1008 - val_cetuc_output_loss: 0.2224
# Epoch 157/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3190 - ser_output_loss: 0.0966 - cetuc_output_loss: 0.2225 - val_loss: 0.3232 - val_ser_output_loss: 0.1007 - val_cetuc_output_loss: 0.2225
# Epoch 158/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3188 - ser_output_loss: 0.0963 - cetuc_output_loss: 0.2225 - val_loss: 0.3232 - val_ser_output_loss: 0.1006 - val_cetuc_output_loss: 0.2226
# Epoch 159/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3186 - ser_output_loss: 0.0961 - cetuc_output_loss: 0.2225 - val_loss: 0.3228 - val_ser_output_loss: 0.1004 - val_cetuc_output_loss: 0.2224
# Epoch 160/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3184 - ser_output_loss: 0.0959 - cetuc_output_loss: 0.2225 - val_loss: 0.3227 - val_ser_output_loss: 0.1003 - val_cetuc_output_loss: 0.2224
# Epoch 161/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3181 - ser_output_loss: 0.0957 - cetuc_output_loss: 0.2224 - val_loss: 0.3228 - val_ser_output_loss: 0.1002 - val_cetuc_output_loss: 0.2226
# Epoch 162/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3180 - ser_output_loss: 0.0955 - cetuc_output_loss: 0.2225 - val_loss: 0.3224 - val_ser_output_loss: 0.1000 - val_cetuc_output_loss: 0.2224
# Epoch 163/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3178 - ser_output_loss: 0.0953 - cetuc_output_loss: 0.2225 - val_loss: 0.3223 - val_ser_output_loss: 0.0999 - val_cetuc_output_loss: 0.2224
# Epoch 164/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3175 - ser_output_loss: 0.0951 - cetuc_output_loss: 0.2224 - val_loss: 0.3223 - val_ser_output_loss: 0.0998 - val_cetuc_output_loss: 0.2225
# Epoch 165/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3174 - ser_output_loss: 0.0949 - cetuc_output_loss: 0.2225 - val_loss: 0.3221 - val_ser_output_loss: 0.0997 - val_cetuc_output_loss: 0.2224
# Epoch 166/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3172 - ser_output_loss: 0.0947 - cetuc_output_loss: 0.2224 - val_loss: 0.3219 - val_ser_output_loss: 0.0996 - val_cetuc_output_loss: 0.2224
# Epoch 167/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3169 - ser_output_loss: 0.0945 - cetuc_output_loss: 0.2224 - val_loss: 0.3219 - val_ser_output_loss: 0.0995 - val_cetuc_output_loss: 0.2224
# Epoch 168/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3168 - ser_output_loss: 0.0943 - cetuc_output_loss: 0.2224 - val_loss: 0.3218 - val_ser_output_loss: 0.0994 - val_cetuc_output_loss: 0.2224
# Epoch 169/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3166 - ser_output_loss: 0.0942 - cetuc_output_loss: 0.2224 - val_loss: 0.3216 - val_ser_output_loss: 0.0993 - val_cetuc_output_loss: 0.2224
# Epoch 170/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3164 - ser_output_loss: 0.0940 - cetuc_output_loss: 0.2224 - val_loss: 0.3216 - val_ser_output_loss: 0.0991 - val_cetuc_output_loss: 0.2224
# Epoch 171/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3162 - ser_output_loss: 0.0938 - cetuc_output_loss: 0.2224 - val_loss: 0.3214 - val_ser_output_loss: 0.0990 - val_cetuc_output_loss: 0.2224
# Epoch 172/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3161 - ser_output_loss: 0.0937 - cetuc_output_loss: 0.2224 - val_loss: 0.3213 - val_ser_output_loss: 0.0989 - val_cetuc_output_loss: 0.2224
# Epoch 173/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3159 - ser_output_loss: 0.0935 - cetuc_output_loss: 0.2224 - val_loss: 0.3212 - val_ser_output_loss: 0.0988 - val_cetuc_output_loss: 0.2224
# Epoch 174/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3157 - ser_output_loss: 0.0933 - cetuc_output_loss: 0.2224 - val_loss: 0.3211 - val_ser_output_loss: 0.0987 - val_cetuc_output_loss: 0.2224
# Epoch 175/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3156 - ser_output_loss: 0.0932 - cetuc_output_loss: 0.2224 - val_loss: 0.3210 - val_ser_output_loss: 0.0986 - val_cetuc_output_loss: 0.2224
# Epoch 176/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3154 - ser_output_loss: 0.0930 - cetuc_output_loss: 0.2224 - val_loss: 0.3209 - val_ser_output_loss: 0.0985 - val_cetuc_output_loss: 0.2224
# Epoch 177/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3152 - ser_output_loss: 0.0929 - cetuc_output_loss: 0.2224 - val_loss: 0.3208 - val_ser_output_loss: 0.0985 - val_cetuc_output_loss: 0.2224
# Epoch 178/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3151 - ser_output_loss: 0.0927 - cetuc_output_loss: 0.2224 - val_loss: 0.3207 - val_ser_output_loss: 0.0984 - val_cetuc_output_loss: 0.2224
# Epoch 179/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3149 - ser_output_loss: 0.0925 - cetuc_output_loss: 0.2224 - val_loss: 0.3206 - val_ser_output_loss: 0.0983 - val_cetuc_output_loss: 0.2224
# Epoch 180/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3148 - ser_output_loss: 0.0924 - cetuc_output_loss: 0.2224 - val_loss: 0.3206 - val_ser_output_loss: 0.0982 - val_cetuc_output_loss: 0.2224
# Epoch 181/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3146 - ser_output_loss: 0.0923 - cetuc_output_loss: 0.2224 - val_loss: 0.3205 - val_ser_output_loss: 0.0981 - val_cetuc_output_loss: 0.2224
# Epoch 182/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3145 - ser_output_loss: 0.0921 - cetuc_output_loss: 0.2224 - val_loss: 0.3204 - val_ser_output_loss: 0.0980 - val_cetuc_output_loss: 0.2223
# Epoch 183/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3144 - ser_output_loss: 0.0920 - cetuc_output_loss: 0.2224 - val_loss: 0.3203 - val_ser_output_loss: 0.0979 - val_cetuc_output_loss: 0.2224
# Epoch 184/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3142 - ser_output_loss: 0.0918 - cetuc_output_loss: 0.2224 - val_loss: 0.3203 - val_ser_output_loss: 0.0979 - val_cetuc_output_loss: 0.2224
# Epoch 185/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3141 - ser_output_loss: 0.0917 - cetuc_output_loss: 0.2224 - val_loss: 0.3201 - val_ser_output_loss: 0.0978 - val_cetuc_output_loss: 0.2223
# Epoch 186/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3139 - ser_output_loss: 0.0915 - cetuc_output_loss: 0.2224 - val_loss: 0.3201 - val_ser_output_loss: 0.0977 - val_cetuc_output_loss: 0.2224
# Epoch 187/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3138 - ser_output_loss: 0.0914 - cetuc_output_loss: 0.2224 - val_loss: 0.3200 - val_ser_output_loss: 0.0976 - val_cetuc_output_loss: 0.2224
# Epoch 188/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3137 - ser_output_loss: 0.0913 - cetuc_output_loss: 0.2224 - val_loss: 0.3199 - val_ser_output_loss: 0.0976 - val_cetuc_output_loss: 0.2223
# Epoch 189/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3135 - ser_output_loss: 0.0911 - cetuc_output_loss: 0.2224 - val_loss: 0.3199 - val_ser_output_loss: 0.0975 - val_cetuc_output_loss: 0.2224
# Epoch 190/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3134 - ser_output_loss: 0.0910 - cetuc_output_loss: 0.2224 - val_loss: 0.3198 - val_ser_output_loss: 0.0974 - val_cetuc_output_loss: 0.2224
# Epoch 191/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3133 - ser_output_loss: 0.0909 - cetuc_output_loss: 0.2224 - val_loss: 0.3197 - val_ser_output_loss: 0.0973 - val_cetuc_output_loss: 0.2223
# Epoch 192/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3132 - ser_output_loss: 0.0908 - cetuc_output_loss: 0.2224 - val_loss: 0.3197 - val_ser_output_loss: 0.0973 - val_cetuc_output_loss: 0.2224
# Epoch 193/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3130 - ser_output_loss: 0.0906 - cetuc_output_loss: 0.2224 - val_loss: 0.3197 - val_ser_output_loss: 0.0972 - val_cetuc_output_loss: 0.2225
# Epoch 194/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3129 - ser_output_loss: 0.0905 - cetuc_output_loss: 0.2224 - val_loss: 0.3195 - val_ser_output_loss: 0.0971 - val_cetuc_output_loss: 0.2224
# Epoch 195/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3128 - ser_output_loss: 0.0904 - cetuc_output_loss: 0.2224 - val_loss: 0.3195 - val_ser_output_loss: 0.0971 - val_cetuc_output_loss: 0.2224
# Epoch 196/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3127 - ser_output_loss: 0.0903 - cetuc_output_loss: 0.2224 - val_loss: 0.3195 - val_ser_output_loss: 0.0970 - val_cetuc_output_loss: 0.2225
# Epoch 197/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3126 - ser_output_loss: 0.0902 - cetuc_output_loss: 0.2224 - val_loss: 0.3193 - val_ser_output_loss: 0.0970 - val_cetuc_output_loss: 0.2224
# Epoch 198/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3125 - ser_output_loss: 0.0900 - cetuc_output_loss: 0.2224 - val_loss: 0.3193 - val_ser_output_loss: 0.0969 - val_cetuc_output_loss: 0.2224
# Epoch 199/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3123 - ser_output_loss: 0.0899 - cetuc_output_loss: 0.2224 - val_loss: 0.3194 - val_ser_output_loss: 0.0968 - val_cetuc_output_loss: 0.2225
# Epoch 200/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3123 - ser_output_loss: 0.0898 - cetuc_output_loss: 0.2225 - val_loss: 0.3192 - val_ser_output_loss: 0.0968 - val_cetuc_output_loss: 0.2224
# Epoch 201/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3122 - ser_output_loss: 0.0897 - cetuc_output_loss: 0.2225 - val_loss: 0.3191 - val_ser_output_loss: 0.0967 - val_cetuc_output_loss: 0.2223
# Epoch 202/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3120 - ser_output_loss: 0.0896 - cetuc_output_loss: 0.2224 - val_loss: 0.3192 - val_ser_output_loss: 0.0967 - val_cetuc_output_loss: 0.2226
# Epoch 203/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3119 - ser_output_loss: 0.0895 - cetuc_output_loss: 0.2225 - val_loss: 0.3191 - val_ser_output_loss: 0.0966 - val_cetuc_output_loss: 0.2225
# Epoch 204/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3119 - ser_output_loss: 0.0894 - cetuc_output_loss: 0.2225 - val_loss: 0.3189 - val_ser_output_loss: 0.0965 - val_cetuc_output_loss: 0.2223
# Epoch 205/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3116 - ser_output_loss: 0.0892 - cetuc_output_loss: 0.2224 - val_loss: 0.3190 - val_ser_output_loss: 0.0965 - val_cetuc_output_loss: 0.2226
# Epoch 206/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3116 - ser_output_loss: 0.0891 - cetuc_output_loss: 0.2225 - val_loss: 0.3190 - val_ser_output_loss: 0.0964 - val_cetuc_output_loss: 0.2226
# Epoch 207/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3116 - ser_output_loss: 0.0890 - cetuc_output_loss: 0.2225 - val_loss: 0.3187 - val_ser_output_loss: 0.0964 - val_cetuc_output_loss: 0.2223
# Epoch 208/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3113 - ser_output_loss: 0.0889 - cetuc_output_loss: 0.2224 - val_loss: 0.3188 - val_ser_output_loss: 0.0963 - val_cetuc_output_loss: 0.2225
# Epoch 209/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3113 - ser_output_loss: 0.0888 - cetuc_output_loss: 0.2225 - val_loss: 0.3189 - val_ser_output_loss: 0.0963 - val_cetuc_output_loss: 0.2227
# Epoch 210/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3113 - ser_output_loss: 0.0887 - cetuc_output_loss: 0.2226 - val_loss: 0.3186 - val_ser_output_loss: 0.0962 - val_cetuc_output_loss: 0.2224
# Epoch 211/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3111 - ser_output_loss: 0.0886 - cetuc_output_loss: 0.2225 - val_loss: 0.3186 - val_ser_output_loss: 0.0961 - val_cetuc_output_loss: 0.2224
# Epoch 212/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3110 - ser_output_loss: 0.0885 - cetuc_output_loss: 0.2225 - val_loss: 0.3187 - val_ser_output_loss: 0.0961 - val_cetuc_output_loss: 0.2227
# Epoch 213/300
# 7/7 [==============================] - 0s 13ms/step - loss: 0.3110 - ser_output_loss: 0.0884 - cetuc_output_loss: 0.2225 - val_loss: 0.3185 - val_ser_output_loss: 0.0960 - val_cetuc_output_loss: 0.2225
# Epoch 214/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3108 - ser_output_loss: 0.0883 - cetuc_output_loss: 0.2225 - val_loss: 0.3183 - val_ser_output_loss: 0.0960 - val_cetuc_output_loss: 0.2224
# Epoch 215/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3106 - ser_output_loss: 0.0882 - cetuc_output_loss: 0.2224 - val_loss: 0.3185 - val_ser_output_loss: 0.0959 - val_cetuc_output_loss: 0.2226
# Epoch 216/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3106 - ser_output_loss: 0.0881 - cetuc_output_loss: 0.2225 - val_loss: 0.3184 - val_ser_output_loss: 0.0958 - val_cetuc_output_loss: 0.2225
# Epoch 217/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3105 - ser_output_loss: 0.0880 - cetuc_output_loss: 0.2225 - val_loss: 0.3181 - val_ser_output_loss: 0.0958 - val_cetuc_output_loss: 0.2223
# Epoch 218/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3103 - ser_output_loss: 0.0879 - cetuc_output_loss: 0.2224 - val_loss: 0.3183 - val_ser_output_loss: 0.0957 - val_cetuc_output_loss: 0.2225
# Epoch 219/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3102 - ser_output_loss: 0.0878 - cetuc_output_loss: 0.2224 - val_loss: 0.3182 - val_ser_output_loss: 0.0957 - val_cetuc_output_loss: 0.2225
# Epoch 220/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3101 - ser_output_loss: 0.0877 - cetuc_output_loss: 0.2225 - val_loss: 0.3180 - val_ser_output_loss: 0.0956 - val_cetuc_output_loss: 0.2223
# Epoch 221/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3100 - ser_output_loss: 0.0876 - cetuc_output_loss: 0.2224 - val_loss: 0.3180 - val_ser_output_loss: 0.0956 - val_cetuc_output_loss: 0.2224
# Epoch 222/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3099 - ser_output_loss: 0.0875 - cetuc_output_loss: 0.2224 - val_loss: 0.3180 - val_ser_output_loss: 0.0955 - val_cetuc_output_loss: 0.2225
# Epoch 223/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3098 - ser_output_loss: 0.0874 - cetuc_output_loss: 0.2224 - val_loss: 0.3178 - val_ser_output_loss: 0.0955 - val_cetuc_output_loss: 0.2223
# Epoch 224/300
# ...
# Epoch 240/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3112 - ser_output_loss: 0.0889 - cetuc_output_loss: 0.2223 - val_loss: 0.3217 - val_ser_output_loss: 0.0994 - val_cetuc_output_loss: 0.2223
# Epoch 241/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3111 - ser_output_loss: 0.0888 - cetuc_output_loss: 0.2223 - val_loss: 0.3215 - val_ser_output_loss: 0.0992 - val_cetuc_output_loss: 0.2223
# Epoch 242/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3110 - ser_output_loss: 0.0887 - cetuc_output_loss: 0.2223 - val_loss: 0.3214 - val_ser_output_loss: 0.0991 - val_cetuc_output_loss: 0.2223
# Epoch 243/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3109 - ser_output_loss: 0.0885 - cetuc_output_loss: 0.2223 - val_loss: 0.3213 - val_ser_output_loss: 0.0989 - val_cetuc_output_loss: 0.2223
# Epoch 244/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3107 - ser_output_loss: 0.0884 - cetuc_output_loss: 0.2223 - val_loss: 0.3211 - val_ser_output_loss: 0.0988 - val_cetuc_output_loss: 0.2223
# Epoch 245/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3106 - ser_output_loss: 0.0883 - cetuc_output_loss: 0.2223 - val_loss: 0.3210 - val_ser_output_loss: 0.0987 - val_cetuc_output_loss: 0.2223
# Epoch 246/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3105 - ser_output_loss: 0.0882 - cetuc_output_loss: 0.2223 - val_loss: 0.3209 - val_ser_output_loss: 0.0985 - val_cetuc_output_loss: 0.2223
# Epoch 247/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3104 - ser_output_loss: 0.0881 - cetuc_output_loss: 0.2223 - val_loss: 0.3207 - val_ser_output_loss: 0.0984 - val_cetuc_output_loss: 0.2223
# Epoch 248/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3103 - ser_output_loss: 0.0880 - cetuc_output_loss: 0.2223 - val_loss: 0.3206 - val_ser_output_loss: 0.0983 - val_cetuc_output_loss: 0.2223
# Epoch 249/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3102 - ser_output_loss: 0.0879 - cetuc_output_loss: 0.2223 - val_loss: 0.3205 - val_ser_output_loss: 0.0982 - val_cetuc_output_loss: 0.2223
# Epoch 250/300
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3101 - ser_output_loss: 0.0878 - cetuc_output_loss: 0.2223 - val_loss: 0.3204 - val_ser_output_loss: 0.0981 - val_cetuc_output_loss: 0.2223
# Epoch 251/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3100 - ser_output_loss: 0.0876 - cetuc_output_loss: 0.2223 - val_loss: 0.3203 - val_ser_output_loss: 0.0980 - val_cetuc_output_loss: 0.2223
# Epoch 252/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3099 - ser_output_loss: 0.0875 - cetuc_output_loss: 0.2223 - val_loss: 0.3202 - val_ser_output_loss: 0.0978 - val_cetuc_output_loss: 0.2223
# Epoch 253/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3097 - ser_output_loss: 0.0874 - cetuc_output_loss: 0.2223 - val_loss: 0.3200 - val_ser_output_loss: 0.0977 - val_cetuc_output_loss: 0.2223
# Epoch 254/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3096 - ser_output_loss: 0.0873 - cetuc_output_loss: 0.2223 - val_loss: 0.3199 - val_ser_output_loss: 0.0976 - val_cetuc_output_loss: 0.2223
# Epoch 255/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3095 - ser_output_loss: 0.0872 - cetuc_output_loss: 0.2223 - val_loss: 0.3198 - val_ser_output_loss: 0.0975 - val_cetuc_output_loss: 0.2223
# Epoch 256/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3094 - ser_output_loss: 0.0871 - cetuc_output_loss: 0.2223 - val_loss: 0.3197 - val_ser_output_loss: 0.0974 - val_cetuc_output_loss: 0.2223
# Epoch 257/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3093 - ser_output_loss: 0.0870 - cetuc_output_loss: 0.2223 - val_loss: 0.3196 - val_ser_output_loss: 0.0973 - val_cetuc_output_loss: 0.2223
# Epoch 258/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3092 - ser_output_loss: 0.0869 - cetuc_output_loss: 0.2223 - val_loss: 0.3195 - val_ser_output_loss: 0.0972 - val_cetuc_output_loss: 0.2223
# Epoch 259/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3091 - ser_output_loss: 0.0868 - cetuc_output_loss: 0.2223 - val_loss: 0.3194 - val_ser_output_loss: 0.0971 - val_cetuc_output_loss: 0.2223
# Epoch 260/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3090 - ser_output_loss: 0.0867 - cetuc_output_loss: 0.2223 - val_loss: 0.3193 - val_ser_output_loss: 0.0969 - val_cetuc_output_loss: 0.2223
# Epoch 261/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3089 - ser_output_loss: 0.0866 - cetuc_output_loss: 0.2223 - val_loss: 0.3192 - val_ser_output_loss: 0.0968 - val_cetuc_output_loss: 0.2224
# Epoch 262/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3088 - ser_output_loss: 0.0865 - cetuc_output_loss: 0.2223 - val_loss: 0.3190 - val_ser_output_loss: 0.0967 - val_cetuc_output_loss: 0.2223
# Epoch 263/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3087 - ser_output_loss: 0.0864 - cetuc_output_loss: 0.2223 - val_loss: 0.3189 - val_ser_output_loss: 0.0966 - val_cetuc_output_loss: 0.2223
# Epoch 264/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3086 - ser_output_loss: 0.0863 - cetuc_output_loss: 0.2223 - val_loss: 0.3190 - val_ser_output_loss: 0.0965 - val_cetuc_output_loss: 0.2225
# Epoch 265/300
# 7/7 [==============================] - 0s 14ms/step - loss: 0.3086 - ser_output_loss: 0.0862 - cetuc_output_loss: 0.2224 - val_loss: 0.3188 - val_ser_output_loss: 0.0964 - val_cetuc_output_loss: 0.2223
# Epoch 266/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3085 - ser_output_loss: 0.0861 - cetuc_output_loss: 0.2224 - val_loss: 0.3186 - val_ser_output_loss: 0.0963 - val_cetuc_output_loss: 0.2223
# Epoch 267/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3083 - ser_output_loss: 0.0860 - cetuc_output_loss: 0.2223 - val_loss: 0.3189 - val_ser_output_loss: 0.0962 - val_cetuc_output_loss: 0.2227
# Epoch 268/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3084 - ser_output_loss: 0.0859 - cetuc_output_loss: 0.2225 - val_loss: 0.3184 - val_ser_output_loss: 0.0961 - val_cetuc_output_loss: 0.2223
# Epoch 269/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3083 - ser_output_loss: 0.0858 - cetuc_output_loss: 0.2224 - val_loss: 0.3186 - val_ser_output_loss: 0.0960 - val_cetuc_output_loss: 0.2226
# Epoch 270/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3082 - ser_output_loss: 0.0857 - cetuc_output_loss: 0.2225 - val_loss: 0.3191 - val_ser_output_loss: 0.0959 - val_cetuc_output_loss: 0.2232
# Epoch 271/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3085 - ser_output_loss: 0.0856 - cetuc_output_loss: 0.2229 - val_loss: 0.3181 - val_ser_output_loss: 0.0958 - val_cetuc_output_loss: 0.2223
# Epoch 272/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3082 - ser_output_loss: 0.0855 - cetuc_output_loss: 0.2227 - val_loss: 0.3189 - val_ser_output_loss: 0.0958 - val_cetuc_output_loss: 0.2232
# Epoch 273/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3083 - ser_output_loss: 0.0854 - cetuc_output_loss: 0.2229 - val_loss: 0.3196 - val_ser_output_loss: 0.0956 - val_cetuc_output_loss: 0.2240
# Epoch 274/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3089 - ser_output_loss: 0.0853 - cetuc_output_loss: 0.2235 - val_loss: 0.3179 - val_ser_output_loss: 0.0955 - val_cetuc_output_loss: 0.2224
# Epoch 275/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3082 - ser_output_loss: 0.0853 - cetuc_output_loss: 0.2229 - val_loss: 0.3188 - val_ser_output_loss: 0.0955 - val_cetuc_output_loss: 0.2233
# Epoch 276/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3082 - ser_output_loss: 0.0851 - cetuc_output_loss: 0.2231 - val_loss: 0.3194 - val_ser_output_loss: 0.0953 - val_cetuc_output_loss: 0.2241
# Epoch 277/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3087 - ser_output_loss: 0.0851 - cetuc_output_loss: 0.2236 - val_loss: 0.3179 - val_ser_output_loss: 0.0952 - val_cetuc_output_loss: 0.2227
# Epoch 278/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3078 - ser_output_loss: 0.0850 - cetuc_output_loss: 0.2228 - val_loss: 0.3177 - val_ser_output_loss: 0.0952 - val_cetuc_output_loss: 0.2225
# Epoch 279/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3075 - ser_output_loss: 0.0848 - cetuc_output_loss: 0.2227 - val_loss: 0.3178 - val_ser_output_loss: 0.0951 - val_cetuc_output_loss: 0.2227
# Epoch 280/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3075 - ser_output_loss: 0.0848 - cetuc_output_loss: 0.2227 - val_loss: 0.3174 - val_ser_output_loss: 0.0950 - val_cetuc_output_loss: 0.2224
# Epoch 281/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3071 - ser_output_loss: 0.0847 - cetuc_output_loss: 0.2224 - val_loss: 0.3173 - val_ser_output_loss: 0.0950 - val_cetuc_output_loss: 0.2223
# Epoch 282/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3069 - ser_output_loss: 0.0846 - cetuc_output_loss: 0.2223 - val_loss: 0.3172 - val_ser_output_loss: 0.0949 - val_cetuc_output_loss: 0.2223
# Epoch 283/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3068 - ser_output_loss: 0.0845 - cetuc_output_loss: 0.2223 - val_loss: 0.3171 - val_ser_output_loss: 0.0948 - val_cetuc_output_loss: 0.2223
# Epoch 284/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3067 - ser_output_loss: 0.0845 - cetuc_output_loss: 0.2223 - val_loss: 0.3170 - val_ser_output_loss: 0.0947 - val_cetuc_output_loss: 0.2223
# Epoch 285/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3067 - ser_output_loss: 0.0844 - cetuc_output_loss: 0.2223 - val_loss: 0.3170 - val_ser_output_loss: 0.0947 - val_cetuc_output_loss: 0.2223
# Epoch 286/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3066 - ser_output_loss: 0.0843 - cetuc_output_loss: 0.2223 - val_loss: 0.3169 - val_ser_output_loss: 0.0946 - val_cetuc_output_loss: 0.2223
# Epoch 287/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3065 - ser_output_loss: 0.0842 - cetuc_output_loss: 0.2223 - val_loss: 0.3168 - val_ser_output_loss: 0.0945 - val_cetuc_output_loss: 0.2223
# Epoch 288/300
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3064 - ser_output_loss: 0.0841 - cetuc_output_loss: 0.2223 - val_loss: 0.3167 - val_ser_output_loss: 0.0945 - val_cetuc_output_loss: 0.2223
# Epoch 289/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3063 - ser_output_loss: 0.0840 - cetuc_output_loss: 0.2223 - val_loss: 0.3167 - val_ser_output_loss: 0.0944 - val_cetuc_output_loss: 0.2223
# Epoch 290/300
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3062 - ser_output_loss: 0.0839 - cetuc_output_loss: 0.2223 - val_loss: 0.3166 - val_ser_output_loss: 0.0943 - val_cetuc_output_loss: 0.2223
# Epoch 291/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3062 - ser_output_loss: 0.0839 - cetuc_output_loss: 0.2223 - val_loss: 0.3165 - val_ser_output_loss: 0.0942 - val_cetuc_output_loss: 0.2223
# Epoch 292/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3061 - ser_output_loss: 0.0838 - cetuc_output_loss: 0.2223 - val_loss: 0.3165 - val_ser_output_loss: 0.0942 - val_cetuc_output_loss: 0.2223
# Epoch 293/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3060 - ser_output_loss: 0.0837 - cetuc_output_loss: 0.2223 - val_loss: 0.3164 - val_ser_output_loss: 0.0941 - val_cetuc_output_loss: 0.2223
# Epoch 294/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3059 - ser_output_loss: 0.0836 - cetuc_output_loss: 0.2223 - val_loss: 0.3163 - val_ser_output_loss: 0.0940 - val_cetuc_output_loss: 0.2223
# Epoch 295/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3058 - ser_output_loss: 0.0835 - cetuc_output_loss: 0.2223 - val_loss: 0.3162 - val_ser_output_loss: 0.0939 - val_cetuc_output_loss: 0.2223
# Epoch 296/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3057 - ser_output_loss: 0.0835 - cetuc_output_loss: 0.2223 - val_loss: 0.3162 - val_ser_output_loss: 0.0939 - val_cetuc_output_loss: 0.2223
# Epoch 297/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3057 - ser_output_loss: 0.0834 - cetuc_output_loss: 0.2223 - val_loss: 0.3161 - val_ser_output_loss: 0.0938 - val_cetuc_output_loss: 0.2223
# Epoch 298/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3056 - ser_output_loss: 0.0833 - cetuc_output_loss: 0.2223 - val_loss: 0.3160 - val_ser_output_loss: 0.0937 - val_cetuc_output_loss: 0.2223
# Epoch 299/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3055 - ser_output_loss: 0.0832 - cetuc_output_loss: 0.2223 - val_loss: 0.3159 - val_ser_output_loss: 0.0936 - val_cetuc_output_loss: 0.2223
# Epoch 300/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3054 - ser_output_loss: 0.0831 - cetuc_output_loss: 0.2223 - val_loss: 0.3159 - val_ser_output_loss: 0.0936 - val_cetuc_output_loss: 0.2223
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7e9e4ba830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 0s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.82      0.94      0.87        96
#            1       0.70      0.58      0.63        33
#            2       1.00      0.64      0.78        22
#
#     accuracy                           0.81       151
#    macro avg       0.84      0.72      0.76       151
# weighted avg       0.82      0.81      0.81       151
#
# val_f1:  0.7616325062927004
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3159 - ser_output_loss: 0.0936 - cetuc_output_loss: 0.2223
# ['loss', 'ser_output_loss', 'cetuc_output_loss'] [0.3158702850341797, 0.09358154982328415, 0.22228872776031494]
# Score for fold 5: loss of 0.3158702850341797; ser_output_loss of 9.358154982328415%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - F1-Macro: 0.7040744942333145 - Loss: 0.31429898738861084 - Accuracy: 9.19153317809105%
# ------------------------------------------------------------------------
# > Fold 2 - F1-Macro: 0.7278489873509534 - Loss: 0.3169075846672058 - Accuracy: 9.460534155368805%
# ------------------------------------------------------------------------
# > Fold 3 - F1-Macro: 0.7085814455231931 - Loss: 0.32194191217422485 - Accuracy: 9.964721649885178%
# ------------------------------------------------------------------------
# > Fold 4 - F1-Macro: 0.7287298778186999 - Loss: 0.31497183442115784 - Accuracy: 9.258335828781128%
# ------------------------------------------------------------------------
# > Fold 5 - F1-Macro: 0.7616325062927004 - Loss: 0.3158702850341797 - Accuracy: 9.358154982328415%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > F1-Macro: 0.7261734622437722 (+- 0.020320088037529393)
# > Accuracy: 9.446655958890915 (+- 0.2745793845367789)
# > Loss: 0.3167981207370758
# ------------------------------------------------------------------------
